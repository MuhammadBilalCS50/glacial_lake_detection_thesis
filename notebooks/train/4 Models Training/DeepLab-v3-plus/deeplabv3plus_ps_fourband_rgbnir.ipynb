# %% [markdown]
# # DeepLabV3+ Fine-Tuning — **4 Bands (R,G,B,NIR)** from Planet 8-Band (SuperDove SR)

# %% [markdown]
# This notebook trains a **DeepLabV3+** on **four bands** extracted from Planet **8‑band** GeoTIFF tiles (size **512×512**):
# **R, G, B, NIR**. We use **ImageNet-pretrained** encoders and inflate the first conv 3→4 channels (NIR weights = mean of RGB).

# %% [markdown]
# ## Dependencies

# %%
# %pip install -q torch torchvision timm segmentation-models-pytorch rasterio albumentations pandas scikit-image

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path
import random

IMAGES_DIR = Path("D:/Thesis/glacial_lake_detection_thesis/Training/3 Preparing train data/8_band_outputs/subset_500/images")  # change to your imagery folder
LABELS_DIR = Path("D:/Thesis/glacial_lake_detection_thesis/Training/3 Preparing train data/8_band_outputs/subset_500/labels")  # change to your label folder (same filenames)


# SuperDove SR band map (1-indexed): 1 Coastal, 2 Blue, 3 Green I, 4 Green, 5 Yellow, 6 Red, 7 Red Edge, 8 NIR
RGBNIR_BANDS = (6, 4, 2, 8)  # (R,G,B,NIR)

OUTPUT_DIR = Path("./training_output/subset_500")
(OUTPUT_DIR / "logs").mkdir(parents=True, exist_ok=True)
(OUTPUT_DIR / "models").mkdir(parents=True, exist_ok=True)

NUM_SAMPLES = 500
RANDOM_SEED = 42
VAL_RATIO = 0.2
BATCH_SIZE = 2
NUM_WORKERS = 0
EPOCHS = 10
LR = 1e-3

BACKBONES = ["resnet34", "resnet50", "timm-efficientnet-b0", "mobilenet_v2"]
#BACKBONES = ["timm-efficientnet-b0", "mobilenet_v2"]

random.seed(RANDOM_SEED)

# %% [markdown]
# ## Discover Pairs & Sample

# %%
def list_pairs(images_dir: Path, labels_dir: Path):
    img_files = {p.name: p for p in images_dir.glob("*.tif")}
    lbl_files = {p.name: p for p in labels_dir.glob("*.tif")}
    common = sorted(set(img_files) & set(lbl_files))
    return [(img_files[n], lbl_files[n]) for n in common]

all_pairs = list_pairs(IMAGES_DIR, LABELS_DIR)
if not all_pairs:
    raise RuntimeError(f"No paired .tif files found under {IMAGES_DIR} & {LABELS_DIR}.")

print(f"Found {len(all_pairs)} pairs.")
random.shuffle(all_pairs)
sampled_pairs = all_pairs[:min(NUM_SAMPLES, len(all_pairs))]

split_idx = int(len(sampled_pairs) * (1 - VAL_RATIO))
train_pairs = sampled_pairs[:split_idx]
val_pairs = sampled_pairs[split_idx:]
print(f"Train: {len(train_pairs)}, Val: {len(val_pairs)}")
# Out:
# Found 500 pairs.
# Train: 400, Val: 100

# %% [markdown]
# ## Dataset & Dataloaders

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import rasterio
import albumentations as A

def read_geotiff(path: Path):
    with rasterio.open(path) as src:
        arr = src.read()  # (C,H,W)
    return arr

def select_rgbnir(x: np.ndarray, bands=(6,4,2,8)):
    idx = [b-1 for b in bands]
    return x[idx, ...].astype(np.float32)

def minmax_per_band(x: np.ndarray, eps=1e-6):
    x = x.astype(np.float32)
    for i in range(x.shape[0]):
        vmin = np.min(x[i]); vmax = np.max(x[i])
        if vmax - vmin < eps:
            x[i] = 0.0
        else:
            x[i] = (x[i] - vmin) / (vmax - vmin + eps)
    return x

class LakeTilesRGBNIR(Dataset):
    def __init__(self, pairs, bands=(6,4,2,8), aug=None, normalize=True):
        self.pairs = pairs
        self.bands = bands
        self.aug = aug
        self.normalize = normalize

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        img_path, lbl_path = self.pairs[idx]
        img8 = read_geotiff(img_path)
        img = select_rgbnir(img8, self.bands)   # (4,H,W)

        with rasterio.open(lbl_path) as src:
            lbl = src.read(1)
        lbl = (lbl > 0).astype(np.float32)

        if self.normalize:
            img = minmax_per_band(img)

        img_hwc = np.transpose(img, (1,2,0))    # (H,W,4)
        lbl_hwc = lbl[..., None]

        if self.aug:
            transformed = self.aug(image=img_hwc, mask=lbl_hwc)
            img_hwc = transformed["image"]
            lbl_hwc = transformed["mask"]

        img = torch.from_numpy(np.transpose(img_hwc, (2,0,1))).float()
        lbl = torch.from_numpy(lbl_hwc[...,0]).float()
        return img, lbl

train_aug = A.Compose([A.HorizontalFlip(p=0.5), A.VerticalFlip(p=0.5)])
val_aug   = A.Compose([])

train_ds = LakeTilesRGBNIR(train_pairs, bands=RGBNIR_BANDS, aug=None, normalize=True)
val_ds   = LakeTilesRGBNIR(val_pairs,   bands=RGBNIR_BANDS, aug=None,   normalize=True)

PIN_MEMORY = False
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          pin_memory=PIN_MEMORY)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          pin_memory=PIN_MEMORY)

len(train_ds), len(val_ds)
# Out:
# (400, 100)

# %% [markdown]
# ## Loss & Metrics

# %%
import torch.nn.functional as F

def dice_loss_with_logits(logits, targets, eps=1e-7):
    probs = torch.sigmoid(logits)
    if probs.dim() == 4:
        probs = probs[:,0]
    intersection = (probs * targets).sum(dim=(1,2))
    union = probs.sum(dim=(1,2)) + targets.sum(dim=(1,2)) + eps
    dice = (2 * intersection + eps) / union
    return 1 - dice.mean()

def bce_dice_loss(logits, targets):
    return F.binary_cross_entropy_with_logits(logits, targets) + dice_loss_with_logits(logits, targets)

def compute_metrics_from_logits(logits, targets):
    with torch.no_grad():
        probs = torch.sigmoid(logits)
        preds = (probs > 0.5).float()
        t = targets.float()
        tp = (preds * t).sum(dim=(1,2))
        tn = ((1-preds) * (1-t)).sum(dim=(1,2))
        fp = (preds * (1-t)).sum(dim=(1,2))
        fn = ((1-preds) * t).sum(dim=(1,2))
        eps = 1e-7
        precision = (tp / (tp + fp + eps)).mean().item()
        recall    = (tp / (tp + fn + eps)).mean().item()
        f1        = (2*precision*recall / (precision + recall + eps))
        iou       = (tp / (tp + fp + fn + eps)).mean().item()
        accuracy  = ((tp + tn) / (tp + tn + fp + fn + eps)).mean().item()
        return dict(iou=iou, precision=precision, recall=recall, f1=f1, accuracy=accuracy)

# %% [markdown]
# ## Model — Inflate First Conv 3→4

# %%
import segmentation_models_pytorch as smp
import torch
import torch.nn as nn
from torch import optim
import pandas as pd
from datetime import datetime

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def inflate_first_conv_to_4ch(model: nn.Module):
    first_conv = None
    for m in model.encoder.modules():
        if isinstance(m, nn.Conv2d) and m.in_channels == 3:
            first_conv = m
            break
    if first_conv is None:
        return model

    w = first_conv.weight.data
    out_ch, in_ch, kh, kw = w.shape
    new_conv = nn.Conv2d(4, out_ch, kernel_size=first_conv.kernel_size,
                         stride=first_conv.stride, padding=first_conv.padding,
                         dilation=first_conv.dilation, bias=(first_conv.bias is not None))
    with torch.no_grad():
        mean_rgb = w.mean(dim=1, keepdim=True)
        new_w = torch.cat([w, mean_rgb], dim=1)   # append NIR as mean of RGB
        new_conv.weight.copy_(new_w)
        if first_conv.bias is not None and new_conv.bias is not None:
            new_conv.bias.copy_(first_conv.bias.data)

    # replace in encoder
    for name, module in model.encoder.named_modules():
        if module is first_conv:
            parent = model.encoder
            parts = name.split(".")
            for p in parts[:-1]:
                parent = getattr(parent, p)
            setattr(parent, parts[-1], new_conv)
            break
    return model

def make_DeepLabV3Plus_rgbnir(backbone: str, num_classes: int = 1, pretrained=True):
    encoder_weights = "imagenet" if pretrained else None
    model = smp.DeepLabV3Plus(encoder_name=backbone, encoder_weights=encoder_weights,
                     in_channels=3, classes=num_classes)
    if pretrained:
        model = inflate_first_conv_to_4ch(model)
        model.encoder._in_channels = 4
    else:
        model = smp.DeepLabV3Plus(encoder_name=backbone, encoder_weights=None,
                         in_channels=4, classes=num_classes)
    return model

def run_one_epoch(model, loader, optimizer=None, use_amp=True):
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
    is_train = optimizer is not None
    model.train(is_train)

    total_loss = 0.0; n_batches = 0
    agg = dict(iou=0.0, precision=0.0, recall=0.0, f1=0.0, accuracy=0.0)

    for imgs, lbls in loader:
        imgs, lbls = imgs.to(device), lbls.to(device)
        if is_train: optimizer.zero_grad()

        with torch.cuda.amp.autocast(enabled=use_amp):
            logits = model(imgs)[:,0]
            loss = bce_dice_loss(logits, lbls)

        if is_train:
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        total_loss += loss.item(); n_batches += 1
        m = compute_metrics_from_logits(logits.detach(), lbls.detach())
        for k in agg: agg[k] += m[k]

    avg_loss = total_loss / max(1, n_batches)
    for k in agg: agg[k] /= max(1, n_batches)
    torch.cuda.empty_cache()
    return avg_loss, agg

# Stabilize
#torch.backends.cudnn.benchmark = False
#torch.backends.cudnn.deterministic = True
# Out:
# Device: cuda

# %% [markdown]
# ## Training

# %%
results_csv = OUTPUT_DIR / "logs" / "results.csv"
if not results_csv.exists():
    pd.DataFrame(columns=[
        "timestamp","backbone","epoch","split",
        "loss","iou","precision","recall","f1","accuracy"
    ]).to_csv(results_csv, index=False)

for backbone in BACKBONES:
    print(f"\n=== Training backbone: {backbone} ===")
    model = make_DeepLabV3Plus_rgbnir(backbone, num_classes=1, pretrained=True).to(device)
    optimizer = optim.Adam(model.parameters(), lr=LR)

    best_train_iou = -1.0
    best_path = OUTPUT_DIR / "models" / f"{backbone}_best_train_iou.pt"

    for epoch in range(1, EPOCHS+1):
        train_loss, train_metrics = run_one_epoch(model, train_loader, optimizer, use_amp=True)
        val_loss,   val_metrics   = run_one_epoch(model, val_loader, optimizer=None, use_amp=True)

        print(f"[{backbone}] Epoch {epoch}/{EPOCHS} — "
              f"train IoU={train_metrics['iou']:.4f}  val IoU={val_metrics['iou']:.4f}  "
              f"train Loss={train_loss:.4f}  val Loss={val_loss:.4f}")

        ts = datetime.utcnow().isoformat()
        pd.DataFrame([
            dict(timestamp=ts, backbone=backbone, epoch=epoch, split="train", loss=train_loss, **train_metrics),
            dict(timestamp=ts, backbone=backbone, epoch=epoch, split="val",   loss=val_loss,   **val_metrics),
        ]).to_csv(results_csv, mode="a", index=False, header=False)

        if train_metrics["iou"] > best_train_iou:
            best_train_iou = train_metrics["iou"]
            torch.save({
                "backbone": backbone,
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "best_train_iou": best_train_iou,
            }, best_path)

print(f"Training complete. Logs: {results_csv}")
print(f"Models saved under: {OUTPUT_DIR / 'models'}")
# Out:
# === Training backbone: resnet34 ===
# C:\Users\gg\AppData\Local\Temp\ipykernel_7812\4050800962.py:56: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# C:\Users\gg\AppData\Local\Temp\ipykernel_7812\4050800962.py:67: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# [resnet34] Epoch 1/10 — train IoU=0.3416  val IoU=0.2596  train Loss=0.7454  val Loss=0.7645
# C:\Users\gg\AppData\Local\Temp\ipykernel_7812\4134023430.py:24: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   ts = datetime.utcnow().isoformat()
# [resnet34] Epoch 2/10 — train IoU=0.4090  val IoU=0.4179  train Loss=0.5677  val Loss=0.5633
# [resnet34] Epoch 3/10 — train IoU=0.4275  val IoU=0.4121  train Loss=0.5430  val Loss=0.5716
# [resnet34] Epoch 4/10 — train IoU=0.4606  val IoU=0.4112  train Loss=0.5014  val Loss=0.6051
# [resnet34] Epoch 5/10 — train IoU=0.4570  val IoU=0.4371  train Loss=0.5053  val Loss=0.5480
# [resnet34] Epoch 6/10 — train IoU=0.4914  val IoU=0.4519  train Loss=0.4674  val Loss=0.5236
# [resnet34] Epoch 7/10 — train IoU=0.4911  val IoU=0.3685  train Loss=0.4655  val Loss=0.8228
# [resnet34] Epoch 8/10 — train IoU=0.5060  val IoU=0.4284  train Loss=0.4451  val Loss=0.5703
# [resnet34] Epoch 9/10 — train IoU=0.5004  val IoU=0.4473  train Loss=0.4597  val Loss=0.5246
# [resnet34] Epoch 10/10 — train IoU=0.4872  val IoU=0.4757  train Loss=0.4737  val Loss=0.5016
#
# === Training backbone: resnet50 ===
# [resnet50] Epoch 1/10 — train IoU=0.3324  val IoU=0.3280  train Loss=0.7552  val Loss=0.6515
# [resnet50] Epoch 2/10 — train IoU=0.4100  val IoU=0.4021  train Loss=0.5653  val Loss=0.5680
# [resnet50] Epoch 3/10 — train IoU=0.4429  val IoU=0.4368  train Loss=0.5276  val Loss=0.5397
# [resnet50] Epoch 4/10 — train IoU=0.4457  val IoU=0.3596  train Loss=0.5196  val Loss=0.7829
# [resnet50] Epoch 5/10 — train IoU=0.4545  val IoU=0.4741  train Loss=0.5046  val Loss=0.4907
# [resnet50] Epoch 6/10 — train IoU=0.4450  val IoU=0.4778  train Loss=0.5174  val Loss=0.4921
# [resnet50] Epoch 7/10 — train IoU=0.4640  val IoU=0.3377  train Loss=0.4944  val Loss=0.6800
# [resnet50] Epoch 8/10 — train IoU=0.4871  val IoU=0.4973  train Loss=0.4693  val Loss=0.4763
# [resnet50] Epoch 9/10 — train IoU=0.4838  val IoU=0.4345  train Loss=0.4783  val Loss=0.5314
# [resnet50] Epoch 10/10 — train IoU=0.4752  val IoU=0.4812  train Loss=0.4814  val Loss=0.4835
#
# === Training backbone: timm-efficientnet-b0 ===
# [timm-efficientnet-b0] Epoch 1/10 — train IoU=0.3584  val IoU=0.4598  train Loss=0.7053  val Loss=0.5230
# [timm-efficientnet-b0] Epoch 2/10 — train IoU=0.5086  val IoU=0.5349  train Loss=0.4482  val Loss=0.4185
# [timm-efficientnet-b0] Epoch 3/10 — train IoU=0.5220  val IoU=0.4734  train Loss=0.4271  val Loss=0.5043
# [timm-efficientnet-b0] Epoch 4/10 — train IoU=0.5440  val IoU=0.4964  train Loss=0.4050  val Loss=0.4501
# [timm-efficientnet-b0] Epoch 5/10 — train IoU=0.5442  val IoU=0.5561  train Loss=0.3998  val Loss=0.3934
# [timm-efficientnet-b0] Epoch 6/10 — train IoU=0.5590  val IoU=0.4934  train Loss=0.3855  val Loss=0.4715
# [timm-efficientnet-b0] Epoch 7/10 — train IoU=0.5744  val IoU=0.5262  train Loss=0.3702  val Loss=0.4272
# [timm-efficientnet-b0] Epoch 8/10 — train IoU=0.5799  val IoU=0.5464  train Loss=0.3628  val Loss=0.4034
# [timm-efficientnet-b0] Epoch 9/10 — train IoU=0.5801  val IoU=0.5484  train Loss=0.3600  val Loss=0.3982
# [timm-efficientnet-b0] Epoch 10/10 — train IoU=0.5952  val IoU=0.5719  train Loss=0.3464  val Loss=0.3831
#
# === Training backbone: mobilenet_v2 ===
# [mobilenet_v2] Epoch 1/10 — train IoU=0.3547  val IoU=0.4299  train Loss=0.7232  val Loss=0.5520
# [mobilenet_v2] Epoch 2/10 — train IoU=0.4690  val IoU=0.4305  train Loss=0.5029  val Loss=0.5369
# [mobilenet_v2] Epoch 3/10 — train IoU=0.4902  val IoU=0.4749  train Loss=0.4680  val Loss=0.4833
# [mobilenet_v2] Epoch 4/10 — train IoU=0.5024  val IoU=0.5099  train Loss=0.4511  val Loss=0.4465
# [mobilenet_v2] Epoch 5/10 — train IoU=0.5117  val IoU=0.5183  train Loss=0.4384  val Loss=0.4333
# [mobilenet_v2] Epoch 6/10 — train IoU=0.5241  val IoU=0.5224  train Loss=0.4299  val Loss=0.4282
# [mobilenet_v2] Epoch 7/10 — train IoU=0.5173  val IoU=0.5469  train Loss=0.4279  val Loss=0.4003
# [mobilenet_v2] Epoch 8/10 — train IoU=0.5444  val IoU=0.5201  train Loss=0.4052  val Loss=0.4342
# [mobilenet_v2] Epoch 9/10 — train IoU=0.5608  val IoU=0.4523  train Loss=0.3826  val Loss=0.5112
# [mobilenet_v2] Epoch 10/10 — train IoU=0.5574  val IoU=0.5298  train Loss=0.3889  val Loss=0.4175
# Training complete. Logs: training_output\subset_500\logs\results.csv
# Models saved under: training_output\subset_500\models

# %%
# Switched to DeepLabV3Plus (segmentation_models_pytorch)
import segmentation_models_pytorch as smp

# Ensure encoder_name, in_channels, classes are defined above or set defaults here
encoder_name = globals().get("encoder_name", "resnet34")
encoder_weights = globals().get("encoder_weights", "imagenet")
in_channels = globals().get("in_channels", 3)
classes = globals().get("classes", 1)

model = smp.DeepLabV3Plus(
    encoder_name=encoder_name,
    encoder_weights=encoder_weights,
    in_channels=in_channels,
    classes=classes,
)
model

# %% [markdown]
# # UNet Fine-Tuning for Lake Segmentation — **RGB from Planet 8-Band**
#
# This notebook trains a **UNet** on **RGB** channels extracted from **Planet 8-band** GeoTIFF tiles (size **512×512**).
# We use **ImageNet-pretrained** encoders (ResNet, EfficientNet, MobileNet, …) so transfer learning works as intended.
#
# **What it does**
# - Randomly sample **1,000** image/label pairs by matching filenames.
# - Extract **RGB** from Planet 8-band tiles (defaults to **(6,4,2) = (Red, Green, Blue)** for SuperDove SR).
# - Train/Val split (80/20).
# - Train UNet across multiple **backbones** using **pretrained(ImageNet)** weights.
# - **Loss:** BCE + Soft Dice (good for class imbalance).
# - **Metrics:** IoU, Precision, Recall, F1, Accuracy on **train + val**, logged to CSV.
# - Save **best-train-IoU** checkpoint per backbone.
#
# > If your band ordering is different, **change `RGB_BANDS`** below.

# %% [markdown]
# ## Dependencies

# %%
# If needed, uncomment to install:
# %pip install -q torch torchvision timm segmentation-models-pytorch rasterio albumentations pandas scikit-image

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path
import random

# === REQUIRED: Paths ===
IMAGES_DIR = Path("D:/Thesis/glacial_lake_detection_thesis/Training/3 Preparing train data/rgb_outputs/subset_750/images")  # change to your imagery folder
LABELS_DIR = Path("D:/Thesis/glacial_lake_detection_thesis/Training/3 Preparing train data/rgb_outputs/subset_750/labels")  # change to your label folder (same filenames)

# === PlanetScope SuperDove SR default band mapping (1-indexed) ===
RGB_BANDS = (3, 2, 1)  # (R, G, B) 1-indexed

# === Outputs ===
OUTPUT_DIR = Path("./training_output_rgb/subset_750")
(OUTPUT_DIR / "logs").mkdir(parents=True, exist_ok=True)
(OUTPUT_DIR / "models").mkdir(parents=True, exist_ok=True)

# === Training config ===
NUM_SAMPLES = 750
RANDOM_SEED = 42
VAL_RATIO = 0.2
BATCH_SIZE = 2
NUM_WORKERS = 0
EPOCHS = 10
LR = 1e-3

BACKBONES = ['mit_b0', 'mit_b1', 'mit_b2', 'mit_b3', 'mit_b4', 'mit_b5']

random.seed(RANDOM_SEED)

# %% [markdown]
# ## Discover Pairs & Sample

# %%
def list_pairs(images_dir: Path, labels_dir: Path):
    img_files = {p.name: p for p in images_dir.glob("*.tif")}
    lbl_files = {p.name: p for p in labels_dir.glob("*.tif")}
    common = sorted(set(img_files) & set(lbl_files))
    return [(img_files[n], lbl_files[n]) for n in common]

all_pairs = list_pairs(IMAGES_DIR, LABELS_DIR)
if not all_pairs:
    raise RuntimeError(f"No paired .tif files found under {IMAGES_DIR} & {LABELS_DIR}.")

print(f"Found {len(all_pairs)} pairs.")
random.shuffle(all_pairs)
sampled_pairs = all_pairs[:min(NUM_SAMPLES, len(all_pairs))]

split_idx = int(len(sampled_pairs) * (1 - VAL_RATIO))
train_pairs = sampled_pairs[:split_idx]
val_pairs = sampled_pairs[split_idx:]
print(f"Train: {len(train_pairs)}, Val: {len(val_pairs)}")
# Out:
# Found 750 pairs.
# Train: 600, Val: 150

# %% [markdown]
# ## Dataset & Dataloaders (RGB extraction)
# - Reads 8-band imagery and **selects RGB channels** via `RGB_BANDS` (1-indexed).
# - Per-image **min–max** normalization to [0,1].
# - Light flips for augmentation.

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import rasterio
import albumentations as A

def read_geotiff(path: Path):
    with rasterio.open(path) as src:
        arr = src.read()  # (C,H,W), 1-indexed bands in file
    return arr

def select_rgb(x: np.ndarray, rgb_bands=(6,4,2)):
    idx = [b-1 for b in rgb_bands]
    return x[idx, ...].astype(np.float32)

def minmax_per_band(x: np.ndarray, eps=1e-6):
    x = x.astype(np.float32)
    for i in range(x.shape[0]):
        vmin = np.min(x[i]); vmax = np.max(x[i])
        if vmax - vmin < eps:
            x[i] = 0.0
        else:
            x[i] = (x[i] - vmin) / (vmax - vmin + eps)
    return x

class LakeTilesRGB(Dataset):
    def __init__(self, pairs, rgb_bands=(6,4,2), aug=None, normalize=True):
        self.pairs = pairs
        self.rgb_bands = rgb_bands
        self.aug = aug
        self.normalize = normalize

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        img_path, lbl_path = self.pairs[idx]
        img8 = read_geotiff(img_path)          # (8,H,W)
        img = select_rgb(img8, self.rgb_bands) # (3,H,W)

        with rasterio.open(lbl_path) as src:
            lbl = src.read(1)                  # (H,W)
        lbl = (lbl > 0).astype(np.float32)

        if self.normalize:
            img = minmax_per_band(img)

        # Albumentations expects HWC
        img_hwc = np.transpose(img, (1,2,0))
        lbl_hwc = lbl[..., None]

        if self.aug:
            transformed = self.aug(image=img_hwc, mask=lbl_hwc)
            img_hwc = transformed["image"]
            lbl_hwc = transformed["mask"]

        # Back to CHW
        img = torch.from_numpy(np.transpose(img_hwc, (2,0,1))).float()
        lbl = torch.from_numpy(lbl_hwc[...,0]).float()
        return img, lbl

train_aug = A.Compose([A.HorizontalFlip(p=0.5), A.VerticalFlip(p=0.5)])
val_aug   = A.Compose([])

train_ds = LakeTilesRGB(train_pairs, rgb_bands=RGB_BANDS, aug=None, normalize=True)
val_ds   = LakeTilesRGB(val_pairs,   rgb_bands=RGB_BANDS, aug=None,   normalize=True)

PIN_MEMORY = False
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          pin_memory=PIN_MEMORY)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          pin_memory=PIN_MEMORY)

len(train_ds), len(val_ds)
# Out:
# (600, 150)

# %% [markdown]
# ## Loss & Metrics

# %%
import torch.nn.functional as F

def dice_loss_with_logits(logits, targets, eps=1e-7):
    probs = torch.sigmoid(logits)
    if probs.dim() == 4:
        probs = probs[:,0]
    intersection = (probs * targets).sum(dim=(1,2))
    union = probs.sum(dim=(1,2)) + targets.sum(dim=(1,2)) + eps
    dice = (2 * intersection + eps) / union
    return 1 - dice.mean()

def bce_dice_loss(logits, targets):
    return F.binary_cross_entropy_with_logits(logits, targets) + dice_loss_with_logits(logits, targets)

def compute_metrics_from_logits(logits, targets):
    with torch.no_grad():
        probs = torch.sigmoid(logits)
        preds = (probs > 0.5).float()
        t = targets.float()
        tp = (preds * t).sum(dim=(1,2))
        tn = ((1-preds) * (1-t)).sum(dim=(1,2))
        fp = (preds * (1-t)).sum(dim=(1,2))
        fn = ((1-preds) * t).sum(dim=(1,2))
        eps = 1e-7
        precision = (tp / (tp + fp + eps)).mean().item()
        recall    = (tp / (tp + fn + eps)).mean().item()
        f1        = (2*precision*recall / (precision + recall + eps))
        iou       = (tp / (tp + fp + fn + eps)).mean().item()
        accuracy  = ((tp + tn) / (tp + tn + fp + fn + eps)).mean().item()
        return dict(iou=iou, precision=precision, recall=recall, f1=f1, accuracy=accuracy)

# %% [markdown]
# ## Model & Training (ImageNet-pretrained encoders, in_channels=3)

# %%
import segmentation_models_pytorch as smp
import torch
from torch import optim
import pandas as pd
from datetime import datetime
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def make_segformer_rgb(backbone: str, num_classes: int = 1, pretrained=True):
    encoder_weights = "imagenet" if pretrained else None
    model = smp.Unet(
        encoder_name=backbone,
        encoder_weights=encoder_weights,
        in_channels=3,
        classes=num_classes,
    )
    return model

def run_one_epoch(model, loader, optimizer=None, use_amp=True):
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
    is_train = optimizer is not None
    model.train(is_train)

    total_loss = 0.0; n_batches = 0
    agg = dict(iou=0.0, precision=0.0, recall=0.0, f1=0.0, accuracy=0.0)

    for imgs, lbls in loader:
        imgs, lbls = imgs.to(device), lbls.to(device)
        if is_train: optimizer.zero_grad()

        with torch.cuda.amp.autocast(enabled=use_amp):
            logits = model(imgs)[:,0]
            loss = bce_dice_loss(logits, lbls)

        if is_train:
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        total_loss += loss.item(); n_batches += 1
        m = compute_metrics_from_logits(logits.detach(), lbls.detach())
        for k in agg: agg[k] += m[k]

    avg_loss = total_loss / max(1, n_batches)
    for k in agg: agg[k] /= max(1, n_batches)
    torch.cuda.empty_cache()
    return avg_loss, agg

# Determinism tweaks (optional)
#torch.backends.cudnn.benchmark = False
#torch.backends.cudnn.deterministic = True
# Out:
# Device: cuda

# %%
results_csv = OUTPUT_DIR / "logs" / "results.csv"
if not results_csv.exists():
    pd.DataFrame(columns=[
        "timestamp","backbone","epoch","split",
        "loss","iou","precision","recall","f1","accuracy"
    ]).to_csv(results_csv, index=False)

for backbone in BACKBONES:
    print(f"\n=== Training backbone: {backbone} ===")
    model = make_segformer_rgb(backbone, num_classes=1, pretrained=True).to(device)
    optimizer = optim.Adam(model.parameters(), lr=LR)

    best_val_iou = -1.0
    best_path = OUTPUT_DIR / "models" / f"{backbone}_best_train_iou.pt"

    for epoch in range(1, EPOCHS+1):
        train_loss, train_metrics = run_one_epoch(model, train_loader, optimizer, use_amp=True)
        val_loss,   val_metrics   = run_one_epoch(model, val_loader, optimizer=None, use_amp=True)

        print(f"[{backbone}] Epoch {epoch}/{EPOCHS} — "
              f"train IoU={train_metrics['iou']:.4f}  val IoU={val_metrics['iou']:.4f}  "
              f"train Loss={train_loss:.4f}  val Loss={val_loss:.4f}")

        ts = datetime.utcnow().isoformat()
        pd.DataFrame([
            dict(timestamp=ts, backbone=backbone, epoch=epoch, split="train", loss=train_loss, **train_metrics),
            dict(timestamp=ts, backbone=backbone, epoch=epoch, split="val",   loss=val_loss,   **val_metrics),
        ]).to_csv(results_csv, mode="a", index=False, header=False)

        if val_metrics["iou"] > best_val_iou:
            best_val_iou = val_metrics["iou"]
            torch.save({
                "backbone": backbone,
                "epoch": epoch,
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "best_val_iou": best_val_iou,
            }, best_path)

print(f"Training complete. Logs: {results_csv}")
print(f"Models saved under: {OUTPUT_DIR / 'models'}")
# Out:
# === Training backbone: mit_b0 ===
# config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/14.3M [00:00<?, ?B/s]
# C:\Users\gg\AppData\Local\Temp\ipykernel_23900\3096622034.py:27: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# C:\Users\gg\AppData\Local\Temp\ipykernel_23900\3096622034.py:38: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# [mit_b0] Epoch 1/10 — train IoU=0.2166  val IoU=0.4422  train Loss=0.9069  val Loss=0.5509
# ...

# %% [markdown]
# ## MedSegDiff — Diffusion-based Segmentation (added)
# This section adds a lightweight implementation of a diffusion model for **binary lake segmentation**:
# - The model learns to denoise a **noised ground-truth mask** conditioned on the input image.
# - At training time, we add Gaussian noise to the ground-truth mask and train the network to predict that noise (DDPM-style, L2 loss).
# - At inference, we run the reverse denoising process to sample a mask conditioned on the image.

# %%
# ---- MedSegDiff: core utilities ----
import math, torch, torch.nn as nn, torch.nn.functional as F

# Beta schedule (linear)
def make_beta_schedule(T=300, beta_start=1e-4, beta_end=2e-2, device="cpu"):
    betas = torch.linspace(beta_start, beta_end, T, device=device)
    alphas = 1. - betas
    alpha_bars = torch.cumprod(alphas, dim=0)
    return betas, alphas, alpha_bars

class SinusoidalTimeEmbedding(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
        self.fc = nn.Sequential(
            nn.Linear(dim, dim*2),
            nn.SiLU(),
            nn.Linear(dim*2, dim)
        )

    def forward(self, t, T):
        # t: (B,) integer timesteps
        device = t.device
        half = self.dim // 2
        freqs = torch.exp(
            -math.log(10000) * torch.arange(0, half, device=device).float() / half
        )
        ang = t.float().unsqueeze(1) / T * 2 * math.pi
        emb = torch.cat([torch.sin(ang * freqs), torch.cos(ang * freqs)], dim=1)
        if emb.shape[1] < self.dim:  # pad if odd
            emb = F.pad(emb, (0, self.dim - emb.shape[1]))
        return self.fc(emb)

class ResBlock(nn.Module):
    def __init__(self, in_ch, out_ch, time_dim):
        super().__init__()
        self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.emb = nn.Linear(time_dim, out_ch)
        self.act = nn.SiLU()
        self.skip = (in_ch != out_ch)
        if self.skip:
            self.conv_skip = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x, t_emb):
        h = self.act(self.conv1(x))
        h = h + self.emb(t_emb).unsqueeze(-1).unsqueeze(-2)
        h = self.act(h)
        h = self.conv2(h)
        if self.skip:
            x = self.conv_skip(x)
        return self.act(h + x)

class Down(nn.Module):
    def __init__(self, in_ch, out_ch, time_dim):
        super().__init__()
        self.block1 = ResBlock(in_ch, out_ch, time_dim)
        self.block2 = ResBlock(out_ch, out_ch, time_dim)
        self.pool = nn.AvgPool2d(2)

    def forward(self, x, t_emb):
        x = self.block1(x, t_emb)
        x = self.block2(x, t_emb)
        skip = x
        x = self.pool(x)
        return x, skip

class Up(nn.Module):
    def __init__(self, in_ch, out_ch, time_dim):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)
        self.block1 = ResBlock(in_ch, out_ch, time_dim)
        self.block2 = ResBlock(out_ch, out_ch, time_dim)

    def forward(self, x, skip, t_emb):
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)
        x = self.block1(x, t_emb)
        x = self.block2(x, t_emb)
        return x

class MedSegDiffUNet(nn.Module):
    """
    Predicts noise ε for the GT mask, conditioned on the image.
    Inputs:
      cond_img: (B, C_img, H, W)
      x_t:      (B, 1, H, W) noised mask
      t:        (B,) timesteps
    Output:
      eps_pred: (B, 1, H, W)
    """
    def __init__(self, img_channels=3, base_ch=64, time_dim=256):
        super().__init__()
        self.time_mlp = SinusoidalTimeEmbedding(time_dim)

        # Condition by concatenating cond_img and x_t along channels
        in_ch = img_channels + 1

        self.inc = ResBlock(in_ch, base_ch, time_dim)
        self.down1 = Down(base_ch, base_ch*2, time_dim)
        self.down2 = Down(base_ch*2, base_ch*4, time_dim)
        self.down3 = Down(base_ch*4, base_ch*8, time_dim)

        self.mid1 = ResBlock(base_ch*8, base_ch*8, time_dim)
        self.mid2 = ResBlock(base_ch*8, base_ch*8, time_dim)

        self.up3 = Up(base_ch*8 + base_ch*8, base_ch*4, time_dim)
        self.up2 = Up(base_ch*4 + base_ch*4, base_ch*2, time_dim)
        self.up1 = Up(base_ch*2 + base_ch*2, base_ch, time_dim)

        self.outc = nn.Conv2d(base_ch, 1, 1)

    def forward(self, cond_img, x_t, t, T):
        t_emb = self.time_mlp(t, T)
        x = torch.cat([cond_img, x_t], dim=1)
        x = self.inc(x, t_emb)
        x, s1 = self.down1(x, t_emb)
        x, s2 = self.down2(x, t_emb)
        x, s3 = self.down3(x, t_emb)
        x = self.mid1(x, t_emb)
        x = self.mid2(x, t_emb)
        x = self.up3(x, s3, t_emb)
        x = self.up2(x, s2, t_emb)
        x = self.up1(x, s1, t_emb)
        return self.outc(x)

@torch.no_grad()
def p_sample_step(model, x_t, t, cond_img, betas, alphas, alpha_bars):
    """
    One reverse step: x_{t-1} = 1/sqrt(alpha_t) * (x_t - (1-alpha_t)/sqrt(1-alpha_bar_t) * eps_theta) + sqrt(beta_t) * z
    """
    T = len(betas)
    t_batch = torch.full((x_t.size(0),), t, device=x_t.device, dtype=torch.long)
    eps_pred = model(cond_img, x_t, t_batch, T)
    alpha_t = alphas[t].view(1,1,1,1)
    alpha_bar_t = alpha_bars[t].view(1,1,1,1)
    beta_t = betas[t].view(1,1,1,1)

    mean = (1.0/torch.sqrt(alpha_t)) * (x_t - ((1 - alpha_t) / torch.sqrt(1 - alpha_bar_t)) * eps_pred)
    if t > 0:
        z = torch.randn_like(x_t)
        x_prev = mean + torch.sqrt(beta_t) * z
    else:
        x_prev = mean
    return x_prev

def q_sample(x0, t, alpha_bars):
    """
    Forward diffusion: x_t = sqrt(alpha_bar_t) * x0 + sqrt(1-alpha_bar_t) * eps
    """
    noise = torch.randn_like(x0)
    a_bar = alpha_bars[t].view(-1,1,1,1)
    return torch.sqrt(a_bar) * x0 + torch.sqrt(1 - a_bar) * noise, noise

# %%
# ---- MedSegDiff: training & evaluation loop ----
import torch, time
from pathlib import Path

# Try to reuse loaders and device from previous cells
try:
    _ = train_loader
    _ = val_loader
except NameError:
    raise RuntimeError("Expected train_loader and val_loader to exist from previous cells. Please run earlier cells.")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

DIFF_TRAIN_EPOCHS = 10          # adjust as needed
DIFF_TIMESTEPS    = 300         # fewer steps for speed
DIFF_LR           = 2e-4
DIFF_BASE_CH      = 64

# Infer image channels from a sample batch
sample_img, sample_lbl = next(iter(train_loader))
if isinstance(sample_img, (list, tuple)):
    sample_img = sample_img[0]
img_channels = sample_img.shape[1]

model_diff = MedSegDiffUNet(img_channels=img_channels, base_ch=DIFF_BASE_CH).to(device)
betas, alphas, alpha_bars = make_beta_schedule(T=DIFF_TIMESTEPS, device=device)

opt = torch.optim.AdamW(model_diff.parameters(), lr=DIFF_LR)
scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

out_dir = OUTPUT_DIR / "medsegdiff"
(out_dir / "samples").mkdir(parents=True, exist_ok=True)

def bin_metrics_from_probs(probs, labels, thr=0.5, eps=1e-7):
    # probs: (B,1,H,W) in [0,1], labels: (B,H,W) or (B,1,H,W)
    if labels.ndim == 4:
        labels = labels[:,0]
    else:
        labels = labels
    preds = (probs[:,0] >= thr).float()
    lbls  = labels.float()
    inter = (preds * lbls).sum(dim=(1,2))
    union = (preds + lbls - preds*lbls).sum(dim=(1,2))
    iou   = ((inter + eps) / (union + eps)).mean().item()
    dice  = ((2*inter + eps) / (preds.sum(dim=(1,2)) + lbls.sum(dim=(1,2)) + eps)).mean().item()
    acc   = ((preds == lbls).float().mean(dim=(1,2))).mean().item()
    return {"iou": iou, "dice": dice, "accuracy": acc}

def sample_masks(model, cond_img, steps=50):
    model.eval()
    B, C, H, W = cond_img.shape
    x_t = torch.randn(B, 1, H, W, device=cond_img.device)
    step_indices = torch.linspace(DIFF_TIMESTEPS-1, 0, steps, dtype=torch.long, device=cond_img.device)
    for t in step_indices:
        x_t = p_sample_step(model, x_t, int(t.item()), cond_img, betas, alphas, alpha_bars)
    probs = torch.sigmoid(x_t)  # interpret as mask probability after final step
    return probs

best_val_iou = 0.0
history = []

for epoch in range(1, DIFF_TRAIN_EPOCHS+1):
    model_diff.train()
    t0 = time.time()
    tr_loss = 0.0; nbt = 0

    for imgs, lbls in train_loader:
        imgs = imgs.to(device, non_blocking=True)
        # Expect labels as (B,H,W) or (B,1,H,W) in {0,1}
        if lbls.ndim == 3: lbls = lbls.unsqueeze(1)
        lbls = lbls.float().to(device, non_blocking=True)

        # pick random t per-sample
        t = torch.randint(0, DIFF_TIMESTEPS, (imgs.size(0),), device=device)
        x_t, noise = q_sample(lbls, t, alpha_bars)  # forward diffuse the mask
        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            eps_pred = model_diff(imgs, x_t, t, DIFF_TIMESTEPS)
            loss = F.mse_loss(eps_pred, noise)

        opt.zero_grad(set_to_none=True)
        scaler.scale(loss).backward()
        scaler.step(opt)
        scaler.update()

        tr_loss += loss.item(); nbt += 1

    tr_loss /= max(1, nbt)

    # ---- Validation: compute loss and a quick IoU using sampled masks ----
    model_diff.eval()
    va_loss = 0.0; nbv = 0
    with torch.no_grad():
        for imgs, lbls in val_loader:
            imgs = imgs.to(device)
            if lbls.ndim == 3: lbls = lbls.unsqueeze(1)
            lbls = lbls.float().to(device)
            t = torch.randint(0, DIFF_TIMESTEPS, (imgs.size(0),), device=device)
            x_t, noise = q_sample(lbls, t, alpha_bars)
            eps_pred = model_diff(imgs, x_t, t, DIFF_TIMESTEPS)
            va_loss += F.mse_loss(eps_pred, noise).item(); nbv += 1
        va_loss /= max(1, nbv)

        # Sample a small batch for metric estimation (can be slow)
        imgs_s, lbls_s = next(iter(val_loader))
        imgs_s = imgs_s.to(device)
        lbls_s = lbls_s.to(device)
        probs = sample_masks(model_diff, imgs_s[:4], steps=50)
        metrics = bin_metrics_from_probs(probs, lbls_s[:4])
        val_iou = metrics["iou"]

    history.append({"epoch": epoch, "train_loss": tr_loss, "val_loss": va_loss, **metrics})
    took = time.time() - t0
    print(f"[MedSegDiff] Epoch {epoch}/{DIFF_TRAIN_EPOCHS}  train_loss={tr_loss:.4f}  val_loss={va_loss:.4f}  val_iou~{val_iou:.3f}  ({took:.1f}s)")

    # Save a grid of predictions for visual inspection
    with torch.no_grad():
        import torchvision.utils as vutils
        grid_img = vutils.make_grid(imgs_s[:4].cpu(), nrow=4, normalize=True, scale_each=True)
        grid_pred = vutils.make_grid(probs.repeat(1,3,1,1).cpu(), nrow=4)  # visualize prob as 3ch
        vutils.save_image(grid_img, out_dir / "samples" / f"epoch{epoch:03d}_imgs.png")
        vutils.save_image(grid_pred, out_dir / "samples" / f"epoch{epoch:03d}_preds.png")

    if val_iou > best_val_iou:
        best_val_iou = val_iou
        torch.save({"model": model_diff.state_dict(),
                    "epoch": epoch,
                    "timesteps": DIFF_TIMESTEPS,
                    "img_channels": img_channels},
                   out_dir / "best_medsegdiff.pt")
        print(f"  ↳ New best IoU: {best_val_iou:.3f} — checkpoint saved.")

# Persist training history
import pandas as pd
hist_df = pd.DataFrame(history)
hist_path = out_dir / "history_medsegdiff.csv"
hist_df.to_csv(hist_path, index=False)
print(f"Done. History -> {hist_path}")

# %% [markdown]
# **Usage notes**
# - Run the earlier cells to prepare `train_loader`, `val_loader`, and `OUTPUT_DIR` first.
# - Then run the MedSegDiff cells above to train and evaluate the diffusion-based segmenter.
# - Check `OUTPUT_DIR/medsegdiff/samples/` for prediction grids and `best_medsegdiff.pt` for the best model weights.
